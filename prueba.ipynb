# %% [markdown]
# <a href="https://colab.research.google.com/github/JUANPABLOFUENTESENCINAS/METODOSNUMERICOS/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Python Tutorial

# %%
# This is a simple Python program

message = 'hola metodos numericos'
print(message)

# You can try changing the 'message' variable and running the cell again!
# Out:
# hola metodos numericos

# %% [markdown]
# ESTOY HACIENDO OTRA PRUEBA

# %%
A=5
B=7
C=A+B
print(C)
# Out:
# 12

# %%
D=A*B
print(D)
# Out:
# 35
